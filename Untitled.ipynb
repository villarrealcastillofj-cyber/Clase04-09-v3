# %%
print("Hola, mundo!")
# Out:
# Hola, mundo!

# %%
a=1
b=5
total=a+b
print(total)
# Out:
# 6

# %%
a=5
b=10
total=5*10
print(total)
# Out:
# 50

# %%
# Potencia
e = 2
f = 5
print("La potencia es:", e ** f)
# Out:
# La potencia es: 32

# %%
#corazón
print("<3")
# Out:
# <3
